# %%
# %run ExtractAPI.ipynb
# Out:
# DF created: 0 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/a6f7a8e8-e497-4f77-9881-daba429ea981/download/approved-operating-budget-summary-2023.xlsx
# DF created: 1 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/9e5f9a63-fdeb-46e4-9f5f-8143038de56d/download/approved-operating-budget-summary-2022.xlsx
# Sheetname not found: 2014
# Sheetname not found: 2015
# Sheetname not found: 2016
# Sheetname not found: 2017
# Sheetname not found: 2018
# Sheetname not found: 2019
# Sheetname not found: 2020
# DF created: 2 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/930502fa-87f1-4d71-8b71-4435df594b38/download/2021-open-data2.xlsx
# DF created: 3 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/4e58558a-4773-4cd0-a16a-de481f25cb4d/download/2020-operating-open-data.xlsx
# Sheetname not found: 2014
# Sheetname not found: 2015
# Sheetname not found: 2016
# Sheetname not found: 2017
# Sheetname not found: 2018
# DF created: 4 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/27bc496e-1507-4d2e-b9f8-4392b1d44b5c/download/approved-operating-budget-summary-2019.xlsx
# DF created: 5 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/8ff2e379-2bbf-43ab-83eb-2caa7717d85b/download/approved-operating-budget-summary-2018.xlsx
# DF created: 6 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/393dffb4-2f7a-4ff3-8443-e44796f08782/download/approved-operating-budget-summary-2017.xlsx
# DF created: 7 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/d55a2458-f116-456e-a3be-4a0d867fa190/download/approved-operating-budget-summary-2016.xlsx
# DF created: 9 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/4a87ff46-996b-4768-b833-69e023b1b4c4/download/approved-operating-budget-summary-2015.xlsx
# C:\Users\lukas\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# DF created: 10 - https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/7e23b244-91a7-4e70-9baf-be231ff58d59/download/approved-operating-budget-summary-2014.xlsx
# ------------------------------
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2023],
#       dtype='object')
# DF Size = 20127 Rows.
# --------------------
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2022],
#       dtype='object')
# DF Size = 19714 Rows.
# --------------------
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2021],
#       dtype='object')
# DF Size = 20816 Rows.
# --------------------
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2020],
#       dtype='object')
# DF Size = 17779 Rows.
# --------------------
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2019],
#       dtype='object')
# DF Size = 19428 Rows.
# --------------------
# Index(['Program', 'Service', 'Activity', 'Category Name', 'Expense/Revenue',
#        2018],
#       dtype='object')
# DF Size = 2610 Rows.
# --------------------
# Index(['Program', 'Service', 'Activity', 'Category Name', 'Expense/Revenue',
#        2017],
#       dtype='object')
# DF Size = 2604 Rows.
# --------------------
# Index(['Program', 'Service', 'Category Name', 'Expense/Revenue', ' 2016'], dtype='object')
# DF Size = 1312 Rows.
# --------------------
# RangeIndex(start=0, stop=0, step=1)
# DF Size = 0 Rows.
# --------------------
# Index([        'Program',         'Service',        'Activity',
#          'Category Name',        'Category', 'Expense/Revenue',
#                     2015],
#       dtype='object')
# DF Size = 2631 Rows.
# --------------------
# Index(['Program', 'Category Name', 'Category', 'Expense/Revenue', 2014], dtype='object')
# DF Size = 538 Rows.
# --------------------
# RangeIndex(start=0, stop=0, step=1)
# DF Size = 0 Rows.
# --------------------

# %%
db_list = ["budget2014_db",
           "budget2015_db",
           "budget2016_db",
           "budget2017_db",
           "budget2018_db",
           "budget2019_db",
           "budget2020_db",
           "budget2021_db",
           "budget2022_db",
           "budget2023_db",
           "budget2014_db_exp",
           "budget2015_db_exp",
           "budget2016_db_exp",
           "budget2017_db_exp",
           "budget2018_db_exp",
           "budget2019_db_exp",
           "budget2020_db_exp",
           "budget2021_db_exp",
           "budget2022_db_exp",
           "budget2023_db_exp",
           "budget2014_db_rev",
           "budget2015_db_rev",
           "budget2016_db_rev",
           "budget2017_db_rev",
           "budget2018_db_rev",
           "budget2019_db_rev",
           "budget2020_db_rev",
           "budget2021_db_rev",
           "budget2022_db_rev",
           "budget2023_db_rev",
          ]
df_to_db_list = [budget2014_df,
                 budget2015_df,
                 budget2016_df,
                 budget2017_df,
                 budget2018_df,
                 budget2019_df,
                 budget2020_df,
                 budget2021_df,
                 budget2022_df,
                 budget2023_df,
                 budget2014_df_exp,
                 budget2015_df_exp,
                 budget2016_df_exp,
                 budget2017_df_exp,
                 budget2018_df_exp,
                 budget2019_df_exp,
                 budget2020_df_exp,
                 budget2021_df_exp,
                 budget2022_df_exp,
                 budget2023_df_exp,
                 budget2014_df_rev,
                 budget2015_df_rev,
                 budget2016_df_rev,
                 budget2017_df_rev,
                 budget2018_df_rev,
                 budget2019_df_rev,
                 budget2020_df_rev,
                 budget2021_df_rev,
                 budget2022_df_rev,
                 budget2023_df_rev,
                ]

from pymongo import MongoClient
from pprint import pprint

url = "mongodb+srv://city_toronto:project3@cluster0.gt72z8e.mongodb.net/"

# MongoDB Atlas connection details
connection_string = "mongodb+srv://city_toronto:project3@cluster0.gt72z8e.mongodb.net/"
database_name = 'city_toronto'

# Connect to MongoDB Atlas
client = MongoClient(connection_string)
db = client[database_name]

for i in range(0, len(df_to_db_list)):
    
    collection_name = db_list[i]
    
    if collection_name not in db.list_collection_names():
        db.create_collection(collection_name)

    collection = db[collection_name]

    # Convert dataframe to dictionary format and insert into MongoDB
    data_dict = df_to_db_list[i].to_dict(orient='records')
    collection.insert_many(data_dict)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[2], line 82
#      79 collection_name = db_list[i]
#      81 if collection_name not in db.list_collection_names():
# ---> 82     db.create_collection(collection_name)
#      84 collection = db[collection_name]
#      86 # Convert dataframe to dictionary format and insert into MongoDB
#
# File ~\anaconda3\Lib\site-packages\pymongo\database.py:424, in Database.create_collection(self, name, codec_options, read_preference, write_concern, read_concern, session, **kwargs)
#     419 if ((not s or not s.in_transaction) and
#     420         name in self.list_collection_names(
#     421             filter={"name": name}, session=s)):
#     422     raise CollectionInvalid("collection %s already exists" % name)
# --> 424 return Collection(self, name, True, codec_options,
#     425                   read_preference, write_concern,
#     426                   read_concern, session=s, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:187, in Collection.__init__(self, database, name, create, codec_options, read_preference, write_concern, read_concern, session, **kwargs)
#     185 self.__full_name = _UJOIN % (self.__database.name, self.__name)
#     186 if create or kwargs or collation:
# --> 187     self.__create(kwargs, collation, session)
#     189 self.__write_response_codec_options = self.codec_options._replace(
#     190     unicode_decode_error_handler='replace',
#     191     document_class=dict)
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:264, in Collection.__create(self, options, collation, session)
#     262     cmd.update(options)
#     263 with self._socket_for_writes(session) as sock_info:
# --> 264     self._command(
#     265         sock_info, cmd, read_preference=ReadPreference.PRIMARY,
#     266         write_concern=self._write_concern_for(session),
#     267         collation=collation, session=session)
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:238, in Collection._command(self, sock_info, command, secondary_ok, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     209 """Internal command helper.
#     210
#     211 :Parameters:
#    (...)
#     235   The result document.
#     236 """
#     237 with self.__database.client._tmp_session(session) as s:
# --> 238     return sock_info.command(
#     239         self.__database.name,
#     240         command,
#     241         secondary_ok,
#     242         read_preference or self._read_preference_for(session),
#     243         codec_options or self.codec_options,
#     244         check,
#     245         allowable_errors,
#     246         read_concern=read_concern,
#     247         write_concern=write_concern,
#     248         parse_write_concern_error=True,
#     249         collation=collation,
#     250         session=s,
#     251         client=self.__database.client,
#     252         retryable_write=retryable_write,
#     253         user_fields=user_fields)
#
# File ~\anaconda3\Lib\site-packages\pymongo\pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~\anaconda3\Lib\site-packages\pymongo\network.py:158, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156             client._process_response(response_doc, session)
#     157         if check:
# --> 158             helpers._check_command_response(
#     159                 response_doc, sock_info.max_wire_version, allowable_errors,
#     160                 parse_write_concern_error=parse_write_concern_error)
#     161 except Exception as exc:
#     162     if publish:
#
# File ~\anaconda3\Lib\site-packages\pymongo\helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: you are over your space quota, using 514 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 514 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}
