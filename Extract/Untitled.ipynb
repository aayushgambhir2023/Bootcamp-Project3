# %%
# %run ExtractAPI.ipynb
# Out:
# 0 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/a6f7a8e8-e497-4f77-9881-daba429ea981/download/approved-operating-budget-summary-2023.xlsx
# 1 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/9e5f9a63-fdeb-46e4-9f5f-8143038de56d/download/approved-operating-budget-summary-2022.xlsx
# 2 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/930502fa-87f1-4d71-8b71-4435df594b38/download/2021-open-data2.xlsx
# sheetname failed: 2014
# sheetname failed: 2015
# sheetname failed: 2016
# sheetname failed: 2017
# sheetname failed: 2018
# sheetname failed: 2019
# sheetname failed: 2020
# 3 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/4e58558a-4773-4cd0-a16a-de481f25cb4d/download/2020-operating-open-data.xlsx
# 4 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/27bc496e-1507-4d2e-b9f8-4392b1d44b5c/download/approved-operating-budget-summary-2019.xlsx
# sheetname failed: 2014
# sheetname failed: 2015
# sheetname failed: 2016
# sheetname failed: 2017
# sheetname failed: 2018
# 5 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/8ff2e379-2bbf-43ab-83eb-2caa7717d85b/download/approved-operating-budget-summary-2018.xlsx
# 6 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/393dffb4-2f7a-4ff3-8443-e44796f08782/download/approved-operating-budget-summary-2017.xlsx
# 7 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/d55a2458-f116-456e-a3be-4a0d867fa190/download/approved-operating-budget-summary-2016.xlsx
# 9 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/4a87ff46-996b-4768-b833-69e023b1b4c4/download/approved-operating-budget-summary-2015.xlsx
# 10 https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/2c90a5d3-5598-4c02-abf2-169456c8f1f1/resource/7e23b244-91a7-4e70-9baf-be231ff58d59/download/approved-operating-budget-summary-2014.xlsx
# /Users/aayushgambhir/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# 20127
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2023],
#       dtype='object')
# --------------------
# 19714
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2022],
#       dtype='object')
# --------------------
# 20816
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2021],
#       dtype='object')
# --------------------
# 17779
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2020],
#       dtype='object')
# --------------------
# 19428
# Index([          'Program',           'Service',          'Activity',
#          'Expense/Revenue',     'Category Name', 'Sub-Category Name',
#          'Commitment item',                2019],
#       dtype='object')
# --------------------
# 2610
# Index(['Program', 'Service', 'Activity', 'Category Name', 'Expense/Revenue',
#        2018],
#       dtype='object')
# --------------------
# 2604
# Index(['Program', 'Service', 'Activity', 'Category Name', 'Expense/Revenue',
#        2017],
#       dtype='object')
# --------------------
# 1312
# Index(['Program', 'Service', 'Category Name', 'Expense/Revenue', ' 2016'], dtype='object')
# --------------------
# 0
# RangeIndex(start=0, stop=0, step=1)
# --------------------
# 2631
# Index([        'Program',         'Service',        'Activity',
#          'Category Name',        'Category', 'Expense/Revenue',
#                     2015],
#       dtype='object')
# --------------------
# 538
# Index(['Program', 'Category Name', 'Category', 'Expense/Revenue', 2014], dtype='object')
# --------------------
# 0
# RangeIndex(start=0, stop=0, step=1)
# --------------------

# %%
#Seperating the dataframes into expense and revenue dataframes
budget2019_df_exp 
budget2020_df_exp 
budget2021_df_exp 
budget2022_df_exp 
budget2023_df_exp
# Out:
#                    Program                        Service      Activity  \
# 0              311 Toronto                311 Development       311 PMO
# 1              311 Toronto                311 Development       311 PMO
# 2              311 Toronto                311 Development       311 PMO
# 3              311 Toronto                311 Development       311 PMO
# 4              311 Toronto                311 Development       311 PMO
# ...                    ...                            ...           ...
# 20118  Yonge-Dundas Square  Public Square And Event Venue  Not assigned
# 20119  Yonge-Dundas Square  Public Square And Event Venue  Not assigned
# 20120  Yonge-Dundas Square  Public Square And Event Venue  Not assigned
# 20121  Yonge-Dundas Square  Public Square And Event Venue  Not assigned
# 20122  Yonge-Dundas Square  Public Square And Event Venue  Not assigned
#
#       Expense/Revenue         Category Name           Sub-Category Name  \
# 0            Expenses              Benefits                    Benefits
# 1            Expenses      Service And Rent           Telecommnuncation
# 2            Expenses              Benefits                    Benefits
# 3            Expenses              Benefits                    Benefits
# 4            Expenses              Benefits                    Benefits
# ...               ...                   ...                         ...
# 20118        Expenses      Service And Rent  Professtional & Consulting
# 20119        Expenses      Service And Rent  Professtional & Consulting
# 20120        Expenses      Service And Rent                     Rentals
# 20121        Expenses      Service And Rent           Telecommnuncation
# 20122        Expenses  Materials & Supplies                      Energy
#
#                      Commitment item  Budgeted amount 2023
# 0                Canada Pension Plan              63293.40
# 1                Cellular Telephones               2830.00
# 2              Comprehensive Medical              72595.32
# 3                        Dental Plan              37800.96
# 4               Employment Insurance              22992.96
# ...                              ...                   ...
# 20118  Professional Services - Audit              10000.00
# 20119  Professional Services - Legal               2500.00
# 20120               Rental Of Office              80000.00
# 20121                      Telephone              25000.00
# 20122                          Water               7000.00
#
# [18576 rows x 8 columns]

# %%
budget2019_df_rev 
budget2020_df_rev 
budget2021_df_rev 
budget2022_df_rev 
budget2023_df_rev
# Out:
#                        Program                             Service  \
# 91                 311 Toronto                     311 Development
# 92                 311 Toronto                311 Service Delivery
# 93                 311 Toronto                311 Service Delivery
# 94                 311 Toronto                311 Service Delivery
# 95                 311 Toronto                311 Service Delivery
# ...                        ...                                 ...
# 20103  Transportation Services  Transportation Safety & Operations
# 20123      Yonge-Dundas Square       Public Square And Event Venue
# 20124      Yonge-Dundas Square       Public Square And Event Venue
# 20125      Yonge-Dundas Square       Public Square And Event Venue
# 20126      Yonge-Dundas Square       Public Square And Event Venue
#
#                                       Activity Expense/Revenue  \
# 91                                     311 PMO        Revenues
# 92                        311 Service Delivery        Revenues
# 93                        311 Service Delivery        Revenues
# 94                        311 Service Delivery        Revenues
# 95                        311 Service Delivery        Revenues
# ...                                        ...             ...
# 20103  Transportation Studies & Investigations        Revenues
# 20123                             Not assigned        Revenues
# 20124                             Not assigned        Revenues
# 20125                             Not assigned        Revenues
# 20126                             Not assigned        Revenues
#
#                                   Category Name  \
# 91                       Transfers From Capital
# 92     Contribution From Reserves/Reserve Funds
# 93                  Inter-Divisional Recoveries
# 94                  Inter-Divisional Recoveries
# 95                  Inter-Divisional Recoveries
# ...                                         ...
# 20103                    Transfers From Capital
# 20123  Contribution From Reserves/Reserve Funds
# 20124                     User Fees & Donations
# 20125                     User Fees & Donations
# 20126                             Other Revenue
#
#                               Sub-Category Name  \
# 91                       Transfers From Capital
# 92     Contribution From Reserves/Reserve Funds
# 93                  Inter-Divisional Recoveries
# 94                  Inter-Divisional Recoveries
# 95                  Inter-Divisional Recoveries
# ...                                         ...
# 20103                    Transfers From Capital
# 20123  Contribution From Reserves/Reserve Funds
# 20124                                 User Fees
# 20125                Licences & Permits Revenue
# 20126                    Miscellaneous Revenues
#
#                         Commitment item  Budgeted amount 2023
# 91          Transfers From Capital Fund           -1745921.89
# 92     Contributions From Reserve Funds            -290495.00
# 93                  IDR - Public Health            -169235.00
# 94     IDR - Solid Waste Mgmt  Services           -4208952.00
# 95                 IDR - Water Services           -2282813.00
# ...                                 ...                   ...
# 20103       Transfers From Capital Fund           -3106050.09
# 20123       Contributions From Reserves             -33519.00
# 20124             Fees, Service Charges            -836250.00
# 20125                  Location Permits            -200000.00
# 20126                    Sundry Revenue            -880000.00
#
# [1551 rows x 8 columns]

# %%
from pymongo import MongoClient
from pprint import pprint

mongodb+srv://city_toronto:project3@cluster0.gt72z8e.mongodb.net/

# MongoDB connection details
host = 'localhost'
port = 27017
database_name = 'proj3'
collection_name = 'Outliers'

# Connect to MongoDB
client = MongoClient(host, port)
db = client[database_name]
collection = db[collection_name]

# Convert dataframe to dictionary format and insert into MongoDB
data_dict = outliers_sum_by_cat_rev.to_dict(orient='records')
collection.insert_many(data_dict)
